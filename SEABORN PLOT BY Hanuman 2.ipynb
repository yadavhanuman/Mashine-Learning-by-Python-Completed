# %%
# Get the tools
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
np.arange(2,8)
# Out:
# array([2, 3, 4, 5, 6, 7])

# %%
a = np.array([[1,2,3],[4,5,6]])
a[1,2]
# Out:
# 6

# %%
s1=pd.Series()
print(pd.Series().empty)
# Out:
# True

# %%
a= np.array([[1,2,3,4,10], [6,7,7,9,11]]) 
print(a[1, -1])
# Out:
# 11

# %%
a=np.array([1,1,1,1,1])
a+10
# Out:
# array([11, 11, 11, 11, 11])

# %% [markdown]
# # Histograme

# %%
penguins= sns.load_dataset('penguins')
penguins.head(1)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
#
#    body_mass_g   sex
# 0       3750.0  Male

# %%
sns.histplot(x='flipper_length_mm',data=penguins,hue='species')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
sns.pointplot(x='sex',y='age',data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# # Scatter plot

# %%
iris=sns.load_dataset('iris')

# %%
iris.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
sns.scatterplot(iris)
# Out:
# <Axes: >

# %% [markdown]
# # Join plot

# %%
tips=sns.load_dataset('tips')

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
sns.jointplot(x='total_bill',y='size',data=tips)

# %% [markdown]
# # Count plot

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
titanic=sns.load_dataset('titanic')
sns.countplot(titanic)
#sns.countplot(x='class',y='sex',data=titanic)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Violin Plot

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
sns.violinplot(tips)
# Out:
# <Axes: >

# %% [markdown]
# # Pairplot

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
sns.pairplot(tips)

# %% [markdown]
# # pair Grid

# %%
sns.PairGrid(tips)

# %% [markdown]
# # Strip plot

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
sns.stripplot(tips)
#sns.stipplot(x='tip',y='total_bill',data=tips)
# Out:
# <Axes: >

# %% [markdown]
# # Box plot

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
sns.boxplot(tips)
# Out:
# <Axes: >

# %%
sns.boxenplot(tips)
# Out:
# <Axes: >
