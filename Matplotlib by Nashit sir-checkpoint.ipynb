# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

x=[20,30,50,60]
y=[5,10,20,25]
#.set_color('blue')

a= {'color':'red','size':12,'family':'arial',}

plt.style.use('classic')

plt.figure(figsize=(4,2))
# Title
plt.title('Hanuman Report',fontdict=a,loc='center')
plt.xlabel('Class')
plt.ylabel('Marks')

#linenstyle=doted(':'),dashed(--),dashdot(-.),none(''),solid(-)
#figersize(width,height)
plt.plot(x,y, color='red',marker= 'x',linestyle= 'dashed')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
import pandas as pd
import matplotlib.pyplot as plt

df =pd.read_csv('marks.csv') 
df
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     75     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     94     74       81              71
# 7     Gulshan Kumar Ray        73     74     83       76              94
# 8    Ashutosh Kumar raj        89     70     89       97              81
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       93              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
import numpy as np
plt.figure(figsize=(7,3))

nsti= np.array(['Allahabad','kanpur','allapur','india'])
strenth =np.array([17,21,17,10])
plt.bar(nsti,strenth)
plt.show()

# %%
plt.figure(figsize=(7,3))
color= ['r','m','pink','green']
plt.title('students marks',fontsize=15)
plt.xlabel('Location')
plt.ylabel('marks')
plt.bar(df['Name'],df['Maths'],color=color,width=0.4,align='center')
plt.show()

# %%
plt.figure(figsize=(7,3))
plt.barh(df['Name'],df['Maths'])
plt.show()

# %% [markdown]
# # SCATTER PLOT

# %%
x=[2,3,4,5,6]

y=[9,3,5,6,8]
#(x,y)
plt.figure(figsize=(7,3))
plt.plot(x,y,marker='x',linestyle='none')

plt.scatter(x,y)

# %%
x=np.random.randint(30,40,40)
x
# Out:
# array([39, 32, 36, 33, 33, 35, 31, 36, 32, 34, 35, 34, 34, 36, 36, 39, 37,
#        33, 37, 30, 38, 39, 39, 33, 38, 35, 36, 38, 30, 31, 35, 34, 39, 30,
#        35, 37, 39, 38, 35, 31])

# %%
y=np.random.randint(130,190,40)
y
# Out:
# array([135, 132, 143, 177, 145, 143, 134, 188, 149, 151, 155, 167, 136,
#        135, 183, 153, 179, 187, 164, 153, 168, 139, 182, 147, 153, 175,
#        137, 133, 189, 134, 167, 176, 174, 172, 181, 151, 158, 150, 175,
#        158])

# %%
x= [33, 31, 33, 31, 33, 36, 33, 37, 37, 35, 37, 34, 32, 31, 38, 31, 39,
       30, 30, 33, 35, 38, 30, 36, 33, 37, 37, 37, 31, 30, 32, 35, 38, 36,
       31, 30, 31, 30, 37, 32, 32, 31, 32, 34, 30, 39, 38, 33, 30, 39, 36,
        30, 34, 37, 30, 38, 31, 30, 34, 35, 38, 31, 36, 38, 38, 30,
        35, 30, 39, 37, 31, 38, 37, 32, 30, 36, 36, 37, 39, 34, 34,
        31, 39, 35, 38]

y= [135, 132, 143, 177, 145, 143, 134, 188, 149, 151, 155, 167, 136,
       135, 183, 153, 179, 187, 164, 153, 168, 139, 182, 147, 153, 175,
       137, 133, 189, 134, 167, 176, 174, 172, 181, 151, 158, 150, 175,
       ]

# %%
color=['r','g','m','y','k']
plt.figure(figsize=(7,3))
plt.scatter(x,y,color='g')
plt.show()

# %%
x=[2,3,4,5,6]

y=[9,3,5,6,8]
a=['r','g','b','y','m']
s=[130]
colors=[10,20,30,40,60,80]
plt.figure(figsize=(7,3))

plt.scatter(x,y,color=a,sizes=s,alpha=0.2)
plt.colorbar()
plt.show()

# %%
x=[2,3,4,5,6]

y=[9,3,5,6,8]
a=['r','g','b','y','m']
s=[130]
colors=[1,2,3,4,5]
plt.figure(figsize=(7,3))

plt.scatter(x,y,c=colors,sizes=s,alpha=0.2,cmap='Accent_r')
plt.colorbar()
plt.show()
